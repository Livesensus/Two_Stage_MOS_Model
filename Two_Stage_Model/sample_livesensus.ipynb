# %%
import model_1_2_pipeline

# %%
# target audio file
a_fname = 'VCC_sample_audio.wav'

# see model_1_2_pipeline for parameter settings
model = model_1_2_pipeline.Audio_Model(fname=a_fname, input_signal=False, sec_seg = 1, video = False, video_fortran = False)
model.inference_all(verbose=True)
# Out:
# time st: 0 ed 1
# input: [echo_0, echo_1, zero_norm_0, zero_norm_1, bandwidth, latency] [1.0, 1.0, 0.9329091676576493, 0.6031637429670481, 0.9912109375, 0.5]
# Predicted MOS [2.23419294]
#
#
# time st: 1 ed 2
# input: [echo_0, echo_1, zero_norm_0, zero_norm_1, bandwidth, latency] [0.9468, 0.7722536312933601, 0.9999998552561885, 0.6875499267785242, 0.9091796875, 1.0]
# Predicted MOS [2.84092245]
#
#
# time st: 2 ed 3
# input: [echo_0, echo_1, zero_norm_0, zero_norm_1, bandwidth, latency] [1.0, 1.0, 0.9999998552561885, 0.6288178258653916, 1.0, 1.0]
# Predicted MOS [2.86692342]
#
#
# time st: 3 ed 4
# input: [echo_0, echo_1, zero_norm_0, zero_norm_1, bandwidth, latency] [0.5478000000000001, 0.6977620191956145, 0.9999998552561885, 0.5202633313568875, 0.990234375, 1.0]
# Predicted MOS [2.44485572]
#
#
# time st: 4 ed 5
# input: [echo_0, echo_1, zero_norm_0, zero_norm_1, bandwidth, latency] [1.0, 1.0, 0.9999998552561885, 0.7914214569090235, 0.9951171875, 1.0]
# Predicted MOS [3.47589577]
#
#
# time st: 5 ed 6
# input: [echo_0, echo_1, zero_norm_0, zero_norm_1, bandwidth, latency] [1.0, 1.0, 0.9999998552561885, 0.6892443927582479, 1.0, 1.0]
# Predicted MOS [3.07554598]
#
#
# time st: 6 ed 7
# input: [echo_0, echo_1, zero_norm_0, zero_norm_1, bandwidth, latency] [1.0, 1.0, 0.9999998552561885, 0.8178649063273951, 1.0, 1.0]
# Predicted MOS [3.57114763]
#
#
# time st: 7 ed 8
# input: [echo_0, echo_1, zero_norm_0, zero_norm_1, bandwidth, latency] [1.0, 1.0, 0.9999998552561885, 0.9617636102800795, 0.845703125, 1.0]
# Predicted MOS [3.2099786]
#
#
# time st: 8 ed 9
# input: [echo_0, echo_1, zero_norm_0, zero_norm_1, bandwidth, latency] [1.0, 1.0, 0.9999998552561885, 0.5273274640658288, 0.9912109375, 1.0]
# Predicted MOS [2.59892751]

# %%
print(model.mos_time)
print("average MOS: ", sum(model.mos_time)/len(model.mos_time))
# Out:
# [2.234192935884961, 2.8409224525474164, 2.866923420646984, 2.444855724638835, 3.4758957669631694, 3.0755459787072033, 3.5711476279428616, 3.209978598798547, 2.598927511638075]
# average MOS:  2.9242655575297833
